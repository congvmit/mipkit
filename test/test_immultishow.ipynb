# %%
import numpy as np
import mipkit

# %%
def create_black_img(n):
    return [np.zeros([25, 25]) for _ in range(n)]

# %%
list_img = create_black_img(5)

# %%
mipkit.immulshow(list_img, rows=2, cmap='gray')
# Out:
# /Users/congvo/Workspace/mipkit/mipkit/vis.py:269: UserWarning: `len(list_img_arr)` cannot be divided by rows.
#   warnings.warn(
